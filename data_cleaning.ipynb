# %%
import pandas as pd

# %%
albums = pd.read_csv("data/albums.csv")
albums
# Out:
#                   album_name                song_name
# 0                Iron Maiden                  Prowler
# 1                Iron Maiden        Remember Tomorrow
# 2                Iron Maiden             Running Free
# 3                Iron Maiden     Phantom of the Opera
# 4                Iron Maiden             Transylvania
# ..                       ...                      ...
# 310  The Number Of The Beast         22 Acacia Avenue
# 311  The Number Of The Beast  The Number Of The Beast
# 312  The Number Of The Beast         Run To The Hills
# 313  The Number Of The Beast                 Gangland
# 314  The Number Of The Beast     Hallowed Be Thy Name
#
# [315 rows x 2 columns]

# %%
setlists = pd.read_csv("data/setlist.csv")
setlists
# Out:
#        setlist_id concert_id                   song_name  setlist_position  \
# 0      4bab839a_1   4bab839a               Doctor Doctor                 1
# 1      4bab839a_2   4bab839a   Blade Runner (End Titles)                 2
# 2      4bab839a_3   4bab839a    Caught Somewhere in Time                 3
# 3      4bab839a_4   4bab839a  Stranger in a Strange Land                 4
# 4      4bab839a_5   4bab839a     The Writing on the Wall                 5
# ...           ...        ...                         ...               ...
# 39709  13da7161_3   13da7161                 Iron Maiden                 3
# 39710  13da7161_4   13da7161                Transylvania                 4
# 39711  13da7161_5   13da7161                  Wrathchild                 5
# 39712  13db354d_1   13db354d                   Purgatory                 1
# 39713  13db354d_2   13db354d               Strange World                 2
#
#       cover_info  encore   tape
# 0            UFO   False   True
# 1       Vangelis   False   True
# 2            NaN   False  False
# 3            NaN   False  False
# 4            NaN   False  False
# ...          ...     ...    ...
# 39709        NaN   False  False
# 39710        NaN   False  False
# 39711        NaN   False  False
# 39712   Montrose   False  False
# 39713        NaN   False  False
#
# [39714 rows x 7 columns]

# %% [markdown]
# # Clean albums table

# %%
def clean_albums_table(albums_table):
    """Change some song names in the albums table that differ from the
    setlists table (different capitalization or apostrophes).

    Args:
        albums_table (dataframe): the albums table
    
    Returns:
        albums_table_clean (dataframe): the cleaned albums table
    """
    # Harmonize song names
    replacement_mapping_dict = {
        "Blood on the World’s Hands": "Blood on the World's Hands",
        "Bring Your Daughter… to the Slaughter": "Bring Your Daughter... to the Slaughter",
        "Children Of The Damned": "Children of the Damned",
        "Run To The Hills": "Run to the Hills",
        "The Number Of The Beast": "The Number of the Beast",
    }
    albums_table.replace(replacement_mapping_dict, inplace=True)

    # Add "Total Eclipse" and the corresponding album
    new_row = pd.Series({"album_name": "The Number of the Beast",
                         "song_name": "Total Eclipse"},
                         )
    albums_table = pd.concat([albums_table, new_row.to_frame().T], ignore_index=True)
    
    return albums_table

# %%
albums_clean = clean_albums_table(albums)

# %%
filter = setlists[~setlists['song_name'].isin(albums['song_name'])]
filter = filter.drop_duplicates(subset = "song_name")
filter
# Out:
#         setlist_id concert_id  \
# 0       4bab839a_1   4bab839a
# 1       4bab839a_2   4bab839a
# 17     4bab839a_18   4bab839a
# 51      bab8146_18    bab8146
# 773     7ba666dc_2   7ba666dc
# 827     2ba62cbe_2   2ba62cbe
# 942     13a6b149_9   13a6b149
# 1040   23be88f3_17   23be88f3
# 1583   6bb212ca_16   6bb212ca
# 1839   3bb5900c_17   3bb5900c
# 3025     beb5902_3    beb5902
# 5676    3bc1fcf8_2   3bc1fcf8
# 7688    6bdf1ea6_9   6bdf1ea6
# 8819    73d58e21_2   73d58e21
# 8947     3d5b183_2    3d5b183
# 9588     bd6c5a6_1    bd6c5a6
# 10047   23d7b88f_1   23d7b88f
# 14226  73d2ea51_12   73d2ea51
# 15732  3bd610ac_14   3bd610ac
# 16197  23d64c8f_15   23d64c8f
# 20425    3d79d5b_3    3d79d5b
# 22317  73d39af9_10   73d39af9
# 22996   bd395a6_10    bd395a6
# 23901   13d3a5ed_9   13d3a5ed
# 24274   bd3955e_11    bd3955e
# 24294  1bd39558_11   1bd39558
# 25931   43d3afaf_9   43d3afaf
# 25939  43d3afaf_17   43d3afaf
# 27594   23d3ac47_8   23d3ac47
# 27659   13d6d969_7   13d6d969
# 31266   33d5f45d_7   33d5f45d
# 31267   33d5f45d_8   33d5f45d
# 31320   33d3a4f1_1   33d3a4f1
# 33146   3d3a997_10    3d3a997
# 33205  13d3a991_11   13d3a991
# 33417  73d26e69_11   73d26e69
# 34927  4bd3afb6_10   4bd3afb6
# 39706   3da7167_10    3da7167
#
#                                                song_name  setlist_position  \
# 0                                          Doctor Doctor                 1
# 1                              Blade Runner (End Titles)                 2
# 17                Always Look on the Bright Side of Life                18
# 51                        Always Look on the Bright Side                18
# 773                            Blade Runner (end titles)                 2
# 827                                         Blade Runner                 2
# 942                                Happy Birthday to You                 9
# 1040                                  Churchill's Speech                17
# 1583                                  Churchill’s Speech                16
# 1839                                    Churchill Speech                17
# 3025                                     Aces High Intro                 3
# 5676                                      Rising Mercury                 2
# 7688               Toccata and Fugue in D minor, BWV 565                 9
# 8819                            Mars, The Bringer of War                 2
# 8947                            Mars, the Bringer of War                 2
# 9588                   Transylvania / Churchill's Speech                 1
# 10047                          Intro: Churchill's Speech                 1
# 14226                                  Arthur's Farewell                12
# 15732                         Intro - Churchill's Speech                14
# 16197                               Dance of the Knights                15
# 20425                                          Drum Solo                 3
# 22317                       Intro - "633 Squadron" theme                10
# 22996                                 633 Squadron Theme                10
# 23901                         Intro - 633 Squadron music                 9
# 24274                                       633 Squadron                11
# 24294                          Theme from "633 Squadron"                11
# 25931                                 Blade Runner Intro                 9
# 25939                                        Guitar Solo                17
# 27594                            Blade Runner Soundtrack                 8
# 27659                                  Bladerunner Theme                 7
# 31266                                 Smoke on the Water                 7
# 31267                                               Tush                 8
# 31320  Intro - Main Title from the movie "Where Eagle...                 1
# 33146                       Where Eagles Dare Main Theme                10
# 33205                            Where Eagles Dare Theme                11
# 33417                                     I Got the Fire                11
# 34927                                      Total Eclipse                10
# 39706                                          Jailbreak                10
#
#                             cover_info  encore   tape
# 0                                  UFO   False   True
# 1                             Vangelis   False   True
# 17                        Monty Python    True   True
# 51                        Monty Python    True   True
# 773                           Vangelis   False   True
# 827                           Vangelis   False   True
# 942       Mildred J. Hill & Patty Hill   False  False
# 1040                               NaN    True   True
# 1583                               NaN    True   True
# 1839                               NaN    True   True
# 3025                               NaN   False   True
# 5676                               NaN   False   True
# 7688   Johann Christoph Friedrich Bach   False   True
# 8819                      Gustav Holst   False   True
# 8947                      Gustav Holst   False   True
# 9588                               NaN   False   True
# 10047                              NaN   False   True
# 14226                              NaN   False  False
# 15732                              NaN   False  False
# 16197                              NaN   False  False
# 20425                              NaN   False  False
# 22317                              NaN   False  False
# 22996                              NaN   False  False
# 23901                              NaN   False  False
# 24274                              NaN   False  False
# 24294                              NaN   False  False
# 25931                              NaN   False  False
# 25939                              NaN    True  False
# 27594                              NaN   False  False
# 27659                              NaN   False  False
# 31266                              NaN   False  False
# 31267                              NaN   False  False
# 31320                              NaN   False  False
# 33146                              NaN   False  False
# 33205                              NaN   False  False
# 33417                              NaN   False  False
# 34927                              NaN    True  False
# 39706                              NaN   False  False

# %%
albums_clean = clean_albums_table(albums)
filter2 = setlists[~setlists['song_name'].isin(albums_clean['song_name'])]
filter2 = filter2.drop_duplicates(subset = "song_name")
filter2
# Out:
#         setlist_id concert_id  \
# 0       4bab839a_1   4bab839a
# 1       4bab839a_2   4bab839a
# 17     4bab839a_18   4bab839a
# 51      bab8146_18    bab8146
# 773     7ba666dc_2   7ba666dc
# 827     2ba62cbe_2   2ba62cbe
# 942     13a6b149_9   13a6b149
# 1040   23be88f3_17   23be88f3
# 1583   6bb212ca_16   6bb212ca
# 1839   3bb5900c_17   3bb5900c
# 3025     beb5902_3    beb5902
# 5676    3bc1fcf8_2   3bc1fcf8
# 7688    6bdf1ea6_9   6bdf1ea6
# 8819    73d58e21_2   73d58e21
# 8947     3d5b183_2    3d5b183
# 9588     bd6c5a6_1    bd6c5a6
# 10047   23d7b88f_1   23d7b88f
# 14226  73d2ea51_12   73d2ea51
# 15732  3bd610ac_14   3bd610ac
# 16197  23d64c8f_15   23d64c8f
# 20425    3d79d5b_3    3d79d5b
# 22317  73d39af9_10   73d39af9
# 22996   bd395a6_10    bd395a6
# 23901   13d3a5ed_9   13d3a5ed
# 24274   bd3955e_11    bd3955e
# 24294  1bd39558_11   1bd39558
# 25931   43d3afaf_9   43d3afaf
# 25939  43d3afaf_17   43d3afaf
# 27594   23d3ac47_8   23d3ac47
# 27659   13d6d969_7   13d6d969
# 31266   33d5f45d_7   33d5f45d
# 31267   33d5f45d_8   33d5f45d
# 31320   33d3a4f1_1   33d3a4f1
# 33146   3d3a997_10    3d3a997
# 33205  13d3a991_11   13d3a991
# 33417  73d26e69_11   73d26e69
# 39706   3da7167_10    3da7167
#
#                                                song_name  setlist_position  \
# 0                                          Doctor Doctor                 1
# 1                              Blade Runner (End Titles)                 2
# 17                Always Look on the Bright Side of Life                18
# 51                        Always Look on the Bright Side                18
# 773                            Blade Runner (end titles)                 2
# 827                                         Blade Runner                 2
# 942                                Happy Birthday to You                 9
# 1040                                  Churchill's Speech                17
# 1583                                  Churchill’s Speech                16
# 1839                                    Churchill Speech                17
# 3025                                     Aces High Intro                 3
# 5676                                      Rising Mercury                 2
# 7688               Toccata and Fugue in D minor, BWV 565                 9
# 8819                            Mars, The Bringer of War                 2
# 8947                            Mars, the Bringer of War                 2
# 9588                   Transylvania / Churchill's Speech                 1
# 10047                          Intro: Churchill's Speech                 1
# 14226                                  Arthur's Farewell                12
# 15732                         Intro - Churchill's Speech                14
# 16197                               Dance of the Knights                15
# 20425                                          Drum Solo                 3
# 22317                       Intro - "633 Squadron" theme                10
# 22996                                 633 Squadron Theme                10
# 23901                         Intro - 633 Squadron music                 9
# 24274                                       633 Squadron                11
# 24294                          Theme from "633 Squadron"                11
# 25931                                 Blade Runner Intro                 9
# 25939                                        Guitar Solo                17
# 27594                            Blade Runner Soundtrack                 8
# 27659                                  Bladerunner Theme                 7
# 31266                                 Smoke on the Water                 7
# 31267                                               Tush                 8
# 31320  Intro - Main Title from the movie "Where Eagle...                 1
# 33146                       Where Eagles Dare Main Theme                10
# 33205                            Where Eagles Dare Theme                11
# 33417                                     I Got the Fire                11
# 39706                                          Jailbreak                10
#
#                             cover_info  encore   tape
# 0                                  UFO   False   True
# 1                             Vangelis   False   True
# 17                        Monty Python    True   True
# 51                        Monty Python    True   True
# 773                           Vangelis   False   True
# 827                           Vangelis   False   True
# 942       Mildred J. Hill & Patty Hill   False  False
# 1040                               NaN    True   True
# 1583                               NaN    True   True
# 1839                               NaN    True   True
# 3025                               NaN   False   True
# 5676                               NaN   False   True
# 7688   Johann Christoph Friedrich Bach   False   True
# 8819                      Gustav Holst   False   True
# 8947                      Gustav Holst   False   True
# 9588                               NaN   False   True
# 10047                              NaN   False   True
# 14226                              NaN   False  False
# 15732                              NaN   False  False
# 16197                              NaN   False  False
# 20425                              NaN   False  False
# 22317                              NaN   False  False
# 22996                              NaN   False  False
# 23901                              NaN   False  False
# 24274                              NaN   False  False
# 24294                              NaN   False  False
# 25931                              NaN   False  False
# 25939                              NaN    True  False
# 27594                              NaN   False  False
# 27659                              NaN   False  False
# 31266                              NaN   False  False
# 31267                              NaN   False  False
# 31320                              NaN   False  False
# 33146                              NaN   False  False
# 33205                              NaN   False  False
# 33417                              NaN   False  False
# 39706                              NaN   False  False

# %%
print(albums.shape)
print(albums_clean.shape)
# Out:
# (315, 2)
# (316, 2)

# %% [markdown]
# # Clean setlists table

# %%
def clean_setlists_table(setlists_table):
    """Change some song names in the albums table that differ from the
    setlists table (different capitalization or apostrophes).

    Args:
        albums_table (dataframe): the albums table
    
    Returns:
        albums_table_clean (dataframe): the cleaned albums table
    """
    # Harmonize song names
    replacement_mapping_dict = {
                "633 Squadron": "\"633 Squadron\" Theme",
                "633 Squadron Theme": "\"633 Squadron\" Theme",
                "Intro - \"633 Squadron\" theme": "\"633 Squadron\" Theme",
                "Intro - 633 Squadron music": "\"633 Squadron\" Theme",
                "Theme from \"633 Squadron\"": "\"633 Squadron\" Theme",
                "Always Look on the Bright Side": "Always Look on the Bright Side of Life",
                "Blade Runner": "Blade Runner (End Titles)",
                "Blade Runner (end titles)": "Blade Runner (End Titles)",
                "Blade Runner Intro": "Blade Runner (End Titles)",
                "Blade Runner Soundtrack": "Blade Runner (End Titles)",
                "Bladerunner Theme": "Blade Runner (End Titles)",
                "Churchill Speech": "Churchill's Speech",
                "Churchill’s Speech": "Churchill's Speech",
                "Intro - Churchill's Speech": "Churchill's Speech",
                "Intro: Churchill's Speech": "Churchill's Speech",
                "Intro - Main Title from the movie \"Where Eagles Dare\"": "\"Main Title\" from \"Where Eagles Dare\"",
                "Where Eagles Dare Main Theme": "\"Main Title\" from \"Where Eagles Dare\"",
                "Where Eagles Dare Theme": "\"Main Title\" from \"Where Eagles Dare\"",
                "Mars, The Bringer of War": "Mars, the Bringer of War",}
    setlists_table.replace(replacement_mapping_dict, inplace=True)

    # vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
    # Transylvania / Churchill's Speech --> split --> take 1 set for the individual setlist,
    # split the rows, and make setlist_counter +1 for the setlist.

    # ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

    return setlists_table

# %%
setlists_clean = clean_setlists_table(setlists)

# %%
filter = setlists[~setlists['song_name'].isin(albums['song_name'])]
filter = filter.drop_duplicates(subset = "song_name")
filter
# Out:
#         setlist_id concert_id                               song_name  \
# 0       4bab839a_1   4bab839a                           Doctor Doctor
# 1       4bab839a_2   4bab839a               Blade Runner (End Titles)
# 17     4bab839a_18   4bab839a  Always Look on the Bright Side of Life
# 942     13a6b149_9   13a6b149                   Happy Birthday to You
# 1040   23be88f3_17   23be88f3                      Churchill's Speech
# 3025     beb5902_3    beb5902                         Aces High Intro
# 5676    3bc1fcf8_2   3bc1fcf8                          Rising Mercury
# 7688    6bdf1ea6_9   6bdf1ea6   Toccata and Fugue in D minor, BWV 565
# 8819    73d58e21_2   73d58e21                Mars, the Bringer of War
# 9588     bd6c5a6_1    bd6c5a6       Transylvania / Churchill's Speech
# 14226  73d2ea51_12   73d2ea51                       Arthur's Farewell
# 16197  23d64c8f_15   23d64c8f                    Dance of the Knights
# 20425    3d79d5b_3    3d79d5b                               Drum Solo
# 22317  73d39af9_10   73d39af9                    "633 Squadron" Theme
# 25939  43d3afaf_17   43d3afaf                             Guitar Solo
# 31266   33d5f45d_7   33d5f45d                      Smoke on the Water
# 31267   33d5f45d_8   33d5f45d                                    Tush
# 31320   33d3a4f1_1   33d3a4f1   "Main Title" from "Where Eagles Dare"
# 33417  73d26e69_11   73d26e69                          I Got the Fire
# 34927  4bd3afb6_10   4bd3afb6                           Total Eclipse
# 39706   3da7167_10    3da7167                               Jailbreak
#
#        setlist_position                       cover_info  encore   tape
# 0                     1                              UFO   False   True
# 1                     2                         Vangelis   False   True
# 17                   18                     Monty Python    True   True
# 942                   9     Mildred J. Hill & Patty Hill   False  False
# 1040                 17                              NaN    True   True
# 3025                  3                              NaN   False   True
# 5676                  2                              NaN   False   True
# 7688                  9  Johann Christoph Friedrich Bach   False   True
# 8819                  2                     Gustav Holst   False   True
# 9588                  1                              NaN   False   True
# 14226                12                              NaN   False  False
# 16197                15                              NaN   False  False
# 20425                 3                              NaN   False  False
# 22317                10                              NaN   False  False
# 25939                17                              NaN    True  False
# 31266                 7                              NaN   False  False
# 31267                 8                              NaN   False  False
# 31320                 1                              NaN   False  False
# 33417                11                              NaN   False  False
# 34927                10                              NaN    True  False
# 39706                10                              NaN   False  False

# %%
print(setlists_clean.loc[setlists_clean["song_name"] == "Transylvania / Churchill's Speech", "concert_id"])
# Out:
# 9588      bd6c5a6
# 9833     6bd6dea2
# 9882     3bd6a00c
# 10188    53d6cb21
# 15750    73d3a2bd
# 15979    4bd4affe
# Name: concert_id, dtype: object

# %%
setlists_clean.loc[setlists_clean["song_name"] == "Transylvania / Churchill's Speech", "concert_id"]

# %%
print(albums.shape)
print(albums_clean.shape)

# %%
print(albums_clean)

# %%
print(albums)

# %%
replacement_mapping_dict = {
        "Blood on the World’s Hands": "Blood on the World's Hands",
        "Bring Your Daughter… to the Slaughter": "Bring Your Daughter... to the Slaughter",
        "Children Of The Damned": "Children of the Damned",
        "Run To The Hills": "Run to the Hills",
        "The Number Of The Beast": "The Number of the Beast",
    }
albums.replace(replacement_mapping_dict, inplace=True)
print(albums)

#     # Add "Total Eclipse" and the corresponding album
new_row = pd.Series({"album_name": "The Number of the Beast", "song_name": "Total Eclipse"},)
# 
albums_table = pd.concat([albums, new_row.to_frame().T], ignore_index=True)
print(albums_table)
